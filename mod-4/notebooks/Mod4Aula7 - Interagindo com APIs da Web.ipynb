# %% [markdown]
# # Interagindo com APIs da Web

# %% [markdown]
# ## Operações COPEM
# https://sisweb.tesouro.gov.br/apex/f?p=2941:2:::NO:RP,2:P2_ID_UNIDADE_STN:13
#
# SADIPEM API 1.1.0
# [ Base URL: apidatalake.tesouro.gov.br/ords/sadipem/tt/ ]
#
# - https://dados.gov.br/dataset/operacoes-copem
# - http://apidatalake.tesouro.gov.br/docs/sadipem/#/PVL%20-%20Dados%20B%C3%A1sicos
# - https://conteudo.tesouro.gov.br/manuais/index.php?option=com_content&view=article&id=3095&catid=63&Itemid=274
#
# Requests
# - https://docs.python-requests.org/en/master/

# %%
import pandas as pd
import requests

# %%
url = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=SP&tipo_interessado=Estado'

# %%
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
data_json = r.json()

# %%
print(data_json['items'])
# Out:
# [{'id_pleito': 11263, 'tipo_interessado': 'Estado', 'interessado': 'São Paulo', 'cod_ibge': 35, 'uf': 'SP', 'num_pvl': None, 'status': 'Arquivado', 'num_processo': '17944.001396/2011-16', 'data_protocolo': '2011-09-21T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Interamericano de Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 748633000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '10/10/2011'}, {'id_pleito': 26940, 'tipo_interessado': 'Estado', 'interessado': 'São Paulo', 'cod_ibge': 35, 'uf': 'SP', 'num_pvl': 'PVL02.002362/2017-71', 'status': 'Deferido', 'num_processo': '17944.103065/2017-13', 'data_protocolo': '2017-12-20T15:41:35Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Renegociação de dívidas', 'tipo_credor': 'União', 'credor': 'União', 'moeda': 'Real', 'valor': 223539966235.09, 'pvl_ass
# ...

# %%
pd.DataFrame(data_json['items'])
# Out:
#     id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 0       11263           Estado   São Paulo        35  SP
# 1       26940           Estado   São Paulo        35  SP
# 2       11505           Estado   São Paulo        35  SP
# 3       28058           Estado   São Paulo        35  SP
# 4        6774           Estado   São Paulo        35  SP
# ..        ...              ...         ...       ...  ..
# 81      28862           Estado   São Paulo        35  SP
# 82       6513           Estado   São Paulo        35  SP
# 83       8622           Estado   São Paulo        35  SP
# 84       8284           Estado   São Paulo        35  SP
# 85       4943           Estado   São Paulo        35  SP
#
#                  num_pvl                                             status  \
# 0                   None                                          Arquivado
# 1   PVL02.002362/2017-71                                           Deferido
# ...
